# %%
c=5

# %%
c
# Out:
# 5

# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\'

# %%
os.chdir('D:\\')

# %%
os.getcwd()
# Out:
# 'D:\\'

# %%
pd.read_csv("surveys.csv")
# Out:
#        record_id  month  day  year  plot species  sex   wgt
# 0              1      7   16  1977     2      NL    M   NaN
# 1              2      7   16  1977     3      NL    M   NaN
# 2              3      7   16  1977     2      DM    F   NaN
# 3              4      7   16  1977     7      DM    M   NaN
# 4              5      7   16  1977     3      DM    M   NaN
# 5              6      7   16  1977     1      PF    M   NaN
# 6              7      7   16  1977     2      PE    F   NaN
# 7              8      7   16  1977     1      DM    M   NaN
# 8              9      7   16  1977     1      DM    F   NaN
# 9             10      7   16  1977     6      PF    F   NaN
# 10            11      7   16  1977     5      DS    F   NaN
# 11            12      7   16  1977     7      DM    M   NaN
# 12            13      7   16  1977     3      DM    M   NaN
# 13            14      7   16  1977     8      DM  NaN   NaN
# 14            15      7   16  1977     6      DM    F   NaN
# ...

# %%
surveys_df=pd.read_csv("surveys.csv")

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot species  sex   wgt
# 0              1      7   16  1977     2      NL    M   NaN
# 1              2      7   16  1977     3      NL    M   NaN
# 2              3      7   16  1977     2      DM    F   NaN
# 3              4      7   16  1977     7      DM    M   NaN
# 4              5      7   16  1977     3      DM    M   NaN
# 5              6      7   16  1977     1      PF    M   NaN
# 6              7      7   16  1977     2      PE    F   NaN
# 7              8      7   16  1977     1      DM    M   NaN
# 8              9      7   16  1977     1      DM    F   NaN
# 9             10      7   16  1977     6      PF    F   NaN
# 10            11      7   16  1977     5      DS    F   NaN
# 11            12      7   16  1977     7      DM    M   NaN
# 12            13      7   16  1977     3      DM    M   NaN
# 13            14      7   16  1977     8      DM  NaN   NaN
# 14            15      7   16  1977     6      DM    F   NaN
# ...

# %%
surveys_df.columns
# Out:
# Index([u'record_id', u'month', u'day', u'year', u'plot', u'species', u'sex',
#        u'wgt'],
#       dtype='object')

# %%
surveys_df.head
# Out:
# <bound method DataFrame.head of        record_id  month  day  year  plot species  sex   wgt
# 0              1      7   16  1977     2      NL    M   NaN
# 1              2      7   16  1977     3      NL    M   NaN
# 2              3      7   16  1977     2      DM    F   NaN
# 3              4      7   16  1977     7      DM    M   NaN
# 4              5      7   16  1977     3      DM    M   NaN
# 5              6      7   16  1977     1      PF    M   NaN
# 6              7      7   16  1977     2      PE    F   NaN
# 7              8      7   16  1977     1      DM    M   NaN
# 8              9      7   16  1977     1      DM    F   NaN
# 9             10      7   16  1977     6      PF    F   NaN
# 10            11      7   16  1977     5      DS    F   NaN
# 11            12      7   16  1977     7      DM    M   NaN
# 12            13      7   16  1977     3      DM    M   NaN
# 13            14      7   16  1977     8      DM  NaN   NaN
# ...

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot species sex  wgt
# 0          1      7   16  1977     2      NL   M  NaN
# 1          2      7   16  1977     3      NL   M  NaN
# 2          3      7   16  1977     2      DM   F  NaN
# 3          4      7   16  1977     7      DM   M  NaN
# 4          5      7   16  1977     3      DM   M  NaN

# %%
surveys_df.tail()
# Out:
#        record_id  month  day  year  plot species  sex   wgt
# 35544      35545     12   31  2002    15      AH  NaN   NaN
# 35545      35546     12   31  2002    15      AH  NaN   NaN
# 35546      35547     12   31  2002    10      RM    F  14.0
# 35547      35548     12   31  2002     7      DO    M  51.0
# 35548      35549     12   31  2002     5     NaN  NaN   NaN

# %%
surveys_df.shape
# Out:
# (35549, 8)

# %%
surveys_df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-529dd4f9d122> in <module>()
# ----> 1 surveys_df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
pd.unique(surveys_df.species)
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
# Create a list of unique plot IDs found in the survey data. 
# Call it 'plotNames'

# %%
plotNames = pd.unique(surveys_df.plot)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-c0a4c0f49c56> in <module>()
# ----> 1 plotNames = pd.unique(surveys_df.plot)
#
# c:\python27\lib\site-packages\pandas\core\algorithms.pyc in unique(values)
#     100     uniques
#     101     """
# --> 102     values = com._asarray_tuplesafe(values)
#     103
#     104     f = lambda htype, caster: _unique_generic(values, htype, caster)
#
# c:\python27\lib\site-packages\pandas\core\common.pyc in _asarray_tuplesafe(values, dtype)
#     367
#     368     if not (isinstance(values, (list, tuple)) or hasattr(values, '__array__')):
# --> 369         values = list(values)
#     370     elif isinstance(values, Index):
#     371         return values.values
#
# TypeError: 'FramePlotMethods' object is not iterable

# %%
pd.unique(surveys_df.plot)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-897bccd97626> in <module>()
# ----> 1 pd.unique(surveys_df.plot)
#
# c:\python27\lib\site-packages\pandas\core\algorithms.pyc in unique(values)
#     100     uniques
#     101     """
# --> 102     values = com._asarray_tuplesafe(values)
#     103
#     104     f = lambda htype, caster: _unique_generic(values, htype, caster)
#
# c:\python27\lib\site-packages\pandas\core\common.pyc in _asarray_tuplesafe(values, dtype)
#     367
#     368     if not (isinstance(values, (list, tuple)) or hasattr(values, '__array__')):
# --> 369         values = list(values)
#     370     elif isinstance(values, Index):
#     371         return values.values
#
# TypeError: 'FramePlotMethods' object is not iterable

# %%
pd.unique(surveys_df.'plot')

# %%
pd.unique(surveys_df."plot")

# %%
surveys_df.plot

# %%
surveys_df.record_id

# %%
surveys_df.u'plot'

# %%
pd.unique(surveys_df.sex)

# %%
pd.unique(surveys_df.plot)

# %%
surveys_df.plot

# %%
surveys_df.rename(columns={'plot':'plot_id'}, inplace = True)

# %%
pd.unique(surveys_df.plot_id)
# Out:
# array([ 2,  3,  7,  1,  6,  5,  8,  4, 11, 14, 15, 13,  9, 10, 17, 16, 20,
#        23, 18, 21, 22, 19, 12, 24], dtype=int64)

# %%
plotNames = pd.unique(surveys_df.plot)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-c0a4c0f49c56> in <module>()
# ----> 1 plotNames = pd.unique(surveys_df.plot)
#
# c:\python27\lib\site-packages\pandas\core\algorithms.pyc in unique(values)
#     100     uniques
#     101     """
# --> 102     values = com._asarray_tuplesafe(values)
#     103
#     104     f = lambda htype, caster: _unique_generic(values, htype, caster)
#
# c:\python27\lib\site-packages\pandas\core\common.pyc in _asarray_tuplesafe(values, dtype)
#     367
#     368     if not (isinstance(values, (list, tuple)) or hasattr(values, '__array__')):
# --> 369         values = list(values)
#     370     elif isinstance(values, Index):
#     371         return values.values
#
# TypeError: 'FramePlotMethods' object is not iterable

# %%
plotNames = pd.unique(surveys_df.plot_id)

# %%
plotNames.shape
# Out:
# (24,)

# %%
surveys_df['wgt'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: wgt, dtype: float64

# %%
surveys_df['wgt'].mean()
# Out:
# 42.672428212991356

# %%
sorted = surveys_df.groupby("sex")

# %%
sorted.describe()
# Out:
#                     day         month       plot_id     record_id  \
# sex
# F   count  15690.000000  15690.000000  15690.000000  15690.000000
#     mean      16.007138      6.583047     11.440854  18036.412046
#     std        8.271144      3.367350      6.870684  10423.089000
#     min        1.000000      1.000000      1.000000      3.000000
#     25%        9.000000      4.000000      5.000000   8917.500000
#     50%       16.000000      7.000000     12.000000  18075.500000
#     75%       23.000000     10.000000     17.000000  27250.000000
#     max       31.000000     12.000000     24.000000  35547.000000
# M   count  17348.000000  17348.000000  17348.000000  17348.000000
#     mean      16.184286      6.392668     11.098282  17754.835601
#     std        8.199274      3.420806      6.728713  10132.203323
#     min        1.000000      1.000000      1.000000      1.000000
#     25%        9.000000      3.000000      5.000000   8969.750000
# ...

# %%
sorted.mean()
# Out:
#         record_id     month        day         year    plot_id        wgt
# sex
# F    18036.412046  6.583047  16.007138  1990.644997  11.440854  42.170555
# M    17754.835601  6.392668  16.184286  1990.480401  11.098282  42.995379
# P    22488.000000  7.000000  21.000000  1995.000000   8.000000  13.000000
# R    21704.000000  7.000000  12.000000  1994.000000  12.000000        NaN
# Z    23839.000000  4.000000  15.000000  1996.000000   3.000000  18.000000

# %%
sorted['wgt'].mean()
# Out:
# sex
# F    42.170555
# M    42.995379
# P    13.000000
# R          NaN
# Z    18.000000
# Name: wgt, dtype: float64

# %%
sorted2 = surveys_df.groupby(["species", "sex"])

# %%
sorted2

# %%
sorted2.mean()
# Out:
#                 record_id      month        day         year    plot_id  \
# species sex
# AH      M    22330.000000   6.000000   8.000000  1995.000000  16.000000
#         R    21704.000000   7.000000  12.000000  1994.000000  12.000000
# BA      F    18658.451613   6.387097  13.419355  1990.870968  10.903226
#         M    18385.857143   8.214286  11.642857  1990.500000  10.214286
# DM      F    15448.699605   6.403382  16.320817  1988.787879  11.047431
#         M    16071.827944   6.288658  16.164517  1989.285642  10.785726
# DO      F    17035.387615   6.071101  15.567278  1989.943425   8.229358
#         M    18670.820738   6.137083  16.019332  1991.135911   8.218512
# DS      F     6015.080808   6.536195  15.235690  1981.818182  10.867845
#         M     6151.857480   6.210236  15.746457  1982.003150  10.414173
# NL      F    14693.844444   6.863704  16.647407  1988.099259  12.632593
#         M    13648.402390   6.962151  17.053785  1987.370518  10.958167
# ...

# %%
sorted2["wgt"].mean()
# Out:
# species  sex
# AH       M             NaN
#          R             NaN
# BA       F        9.161290
#          M        7.357143
# DM       F       41.609685
#          M       44.353134
# DO       F       48.531250
#          M       49.135102
# DS       F      117.749548
#          M      122.290984
# NL       F      154.282209
#          M      165.652893
# OL       F       31.065817
#          M       32.068410
# OT       F       24.830904
#          M       23.695382
# OX       F       21.000000
#          M       21.000000
# PB       F       30.210884
#          M       33.816498
# PE       F       22.822183
#          M       20.584906
# PF       F        7.974394
#          M        7.885287
# PH       F       30.850000
#          M       31.454545
# PI       M       19.428571
# PL       F       19.312500
#          M       18.684211
# PM       F       22.125668
#          M       20.801205
# PP       F       17.180670
#          M       17.184486
# ...

# %%
# %matplotlib inline

# %%
species_counts = surveys_df.groupby("species")

# %%
species_counts.describe()
# Out:
#                       day       month     plot_id     record_id        wgt  \
# species
# AB      count  303.000000  303.000000  303.000000    303.000000   0.000000
#         mean    15.788779    4.993399   13.973597  13201.702970        NaN
#         std      8.667608    4.084370    6.921937   5835.874869        NaN
#         min      1.000000    1.000000    1.000000   3126.000000        NaN
#         25%      8.500000    2.000000    7.500000   7604.000000        NaN
#         50%     15.000000    3.000000   13.000000  13829.000000        NaN
#         75%     22.500000    9.000000   20.000000  16981.500000        NaN
#         max     31.000000   12.000000   24.000000  33713.000000        NaN
# AH      count  437.000000  437.000000  437.000000    437.000000   0.000000
#         mean    16.427918    6.565217   14.780320  21631.716247        NaN
#         std      8.911772    3.252871    5.292133   7194.381201        NaN
# ...

# %%
species_counts = surveys_df.groupby("species")['record_id'].count()

# %%
species_counts
# Out:
# species
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
species_counts.describe()
# Out:
# count       48.000000
# mean       724.708333
# std       1728.925837
# min          1.000000
# 25%          5.000000
# 50%         37.500000
# 75%        552.500000
# max      10596.000000
# Name: record_id, dtype: float64

# %%
# %matplotlib inline

# %%
species_counts.plot(kind="bar")

# %%
total_count = surveys_df.record_id.groupby(surveys_df['plot_id']).unique()

# %%
total_count
# Out:
# plot_id
# 1     [6, 8, 9, 78, 80, 218, 222, 239, 263, 270, 276...
# 2     [1, 3, 7, 18, 69, 72, 220, 224, 226, 233, 238,...
# 3     [2, 5, 13, 17, 63, 70, 73, 217, 221, 241, 292,...
# 4     [16, 19, 65, 66, 77, 81, 82, 192, 195, 198, 21...
# 5     [11, 87, 98, 100, 101, 113, 159, 161, 169, 177...
# 6     [10, 15, 83, 92, 109, 162, 167, 180, 243, 252,...
# 7     [4, 12, 64, 67, 71, 79, 190, 193, 196, 324, 41...
# 8     [14, 68, 74, 75, 223, 327, 337, 339, 408, 413,...
# 9     [25, 76, 228, 232, 234, 236, 237, 240, 264, 26...
# 10    [30, 32, 110, 201, 325, 417, 456, 581, 634, 70...
# 11    [20, 28, 29, 33, 37, 39, 91, 99, 104, 108, 111...
# 12    [49, 52, 58, 89, 96, 106, 163, 168, 171, 173, ...
# 13    [23, 24, 35, 116, 136, 145, 146, 147, 151, 219...
# 14    [21, 124, 127, 129, 139, 148, 152, 188, 197, 2...
# 15    [22, 26, 27, 31, 114, 121, 128, 133, 135, 143,...
# 16    [36, 130, 141, 153, 204, 205, 207, 212, 306, 3...
# 17    [34, 38, 118, 123, 134, 142, 187, 189, 191, 20...
# ...

# %%
total_count = surveys_df.groupby("plot_id")['record_id'].count()

# %%
total_count
# Out:
# plot_id
# 1     1995
# 2     2194
# 3     1828
# 4     1969
# 5     1194
# 6     1582
# 7      816
# 8     1891
# 9     1936
# 10     469
# 11    1918
# 12    2365
# 13    1538
# 14    1885
# 15    1069
# 16     646
# 17    2039
# 18    1445
# 19    1189
# 20    1390
# 21    1173
# 22    1399
# 23     571
# 24    1048
# Name: record_id, dtype: int64

# %%
total_count.plot(kind='bar', color='#aa5599')

# %%
import matplotlib.pyplot as plt

# %%
plot_data = surveys_df['plot_id']

# %%
plt.plot(plot_data, label="My data")

# %%
small_dataset = surveys_df[:50]

# %%
plot_data = small_dataset['plot_id']

# %%
plt.plot(plot_data, label="My data")

# %%
plt.show()

# %%
plt.savefig("myplot.png")

# %%
plt.plot(plot_data, label="My data", color='r', linewidth=1)
plt.xlabel("Index")
plt.ylabel("Plot value")
plt.title("Plot values from surveys.csv")
plt.savefig("myplot.png")

# %%
plt.plot(plot_data,'s')
plt.xlabel("Index")
plt.ylabel("Plot value")
plt.title("Plot values from surveys.csv")
plt.savefig("myplot2.png")

# %%
import matplotlib as mpl

# %%
mpl.style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'classic',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn-bright',
#  u'seaborn-poster',
#  u'seaborn-muted',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn',
#  u'seaborn-dark-palette']

# %%
# Plot number of animals caught per plot

# %%
animals_per_plot = surveys_df.groupby("plot_id")['record_id'].count()

# %%
animals_per_plot.plot(kind='bar')

# %%
# Create a plot of average weight across all species

# %%
avg_weight_per_species = surveys_df.groupby("species")['wgt'].mean()

# %%
avg_weight_per_species.plot(kind='bar')

# %%
# Create a plot of average weight across all species per plot

# %%
# How many unique plot IDs are in the data (see above)

# %%
# How many unique species are in the data

# %%
speciesName = pd.unique(surveys_df.species)

# %%
speciesName.shape
# Out:
# (49,)

# %%
len(speciesName)
# Out:
# 49

# %%
surveys_df['species']

# %%
surveys_df

# %%
surveys_df.columns
# Out:
# Index([u'record_id', u'month', u'day', u'year', u'plot', u'species', u'sex',
#        u'wgt'],
#       dtype='object')

# %%
surveys_df['plot_id']
# Out:
# 0         2
# 1         3
# 2         2
# 3         7
# 4         3
# 5         1
# 6         2
# 7         1
# 8         1
# 9         6
# 10        5
# 11        7
# 12        3
# 13        8
# 14        6
# 15        4
# 16        3
# 17        2
# 18        4
# 19       11
# 20       14
# 21       15
# 22       13
# 23       13
# 24        9
# 25       15
# 26       15
# 27       11
# 28       11
# 29       10
#          ..
# 35519     9
# 35520     9
# 35521     9
# 35522     9
# 35523     9
# 35524     9
# 35525     8
# 35526    13
# 35527    13
# 35528    13
# 35529    13
# 35530    13
# 35531    14
# 35532    14
# 35533    14
# 35534    14
# 35535    14
# 35536    14
# 35537    15
# 35538    15
# 35539    15
# 35540    15
# 35541    15
# 35542    15
# 35543    15
# 35544    15
# 35545    15
# 35546    10
# 35547     7
# 35548     5
# Name: plot_id, dtype: int64

# %%
# Styling with matplotlib
# Boxplot
# Histogram / distributions
# # remove NA - df.dropna()
# Lib 'seaborn' ex.: displaying regression

# %%
# Workflow #

# Load in surveys data
# Do some summary stats
# Ask a question
# Create a plot that addresses that question
